# %% [markdown]
# ![Hand with calculator](calculator.png "Calculator")
#
# Did you know that the average return from investing in stocks is 10% per year! But who wants to be average?!
#
# You have been asked to support an investment firm by analyzing trends in high-growth companies. They are interested in understanding which industries are producing the highest valuations and the rate at which new high-value companies are emerging. Providing them with this information gives them a competitive insight as to industry trends and how they should structure their portfolio looking forward.
#
# You have been given access to their `unicorns` database, which contains the following tables:
#
# `dates`
# | Column       | Description                                  |
# |------------- |--------------------------------------------- |
# | company_id   | A unique ID for the company.                 |
# | date_joined  | The date that the company became a unicorn.  |
# | year_founded | The year that the company was founded.       |
#
# `funding`
# | Column           | Description                                  |
# |----------------- |--------------------------------------------- |
# | company_id       | A unique ID for the company.                 |
# | valuation        | Company value in US dollars.                 |
# | funding          | The amount of funding raised in US dollars.  |
# | select_investors | A list of key investors in the company.      |
#
# `industries`
# | Column       | Description                                  |
# |------------- |--------------------------------------------- |
# | company_id   | A unique ID for the company.                 |
# | industry     | The industry that the company operates in.   |
#
# `companies`
# | Column       | Description                                       |
# |------------- |-------------------------------------------------- |
# | company_id   | A unique ID for the company.                      |
# | company      | The name of the company.                          |
# | city         | The city where the company is headquartered.      |
# | country      | The country where the company is headquartered.   |
# | continent    | The continent where the company is headquartered. |

# %% [markdown]
# **First Let Us find out the top-performing industries over the time period in question: 2019-2021**

# %%
SELECT i.industry, COUNT(i.*) AS num_unicorns
FROM industries AS i
INNER JOIN dates AS d
ON i.company_id = d.company_id
WHERE EXTRACT(YEAR FROM d.date_joined) IN (2019,2020, 2021)
GROUP BY i.industry
ORDER BY num_unicorns DESC
LIMIT 3;
# Out:
#                           industry  num_unicorns
# 0                          Fintech           173
# 1     Internet software & services           152
# 2  E-commerce & direct-to-consumer            75

# %% [markdown]
# Next let us breakdown the number of unicorns and the average valuation in billions by Industry and year for all companies

# %%
SELECT i.industry,
		EXTRACT(YEAR FROM d.date_joined) AS year,
		COUNT(*) AS num_unicorns,
		ROUND(AVG(f.valuation)/1000000000,2) AS average_valution_billions
FROM industries AS i
INNER JOIN dates AS d
	ON i.company_id = d.company_id
INNER JOIN funding AS f
	ON i.company_id = f.company_id
WHERE EXTRACT(YEAR FROM d.date_joined) IN (2019,2020,2021)
GROUP BY i.industry, year
ORDER BY i.industry, year DESC
# Out:
#                                industry  ...  average_valution_billions
# 0               Artificial intelligence  ...                       1.42
# 1               Artificial intelligence  ...                       4.00
# 2               Artificial intelligence  ...                       4.50
# 3                 Auto & transportation  ...                       3.75
# 4                 Auto & transportation  ...                       3.00
# 5                 Auto & transportation  ...                       4.17
# 6                     Consumer & retail  ...                       2.57
# 7                     Consumer & retail  ...                      15.00
# 8                     Consumer & retail  ...                       3.67
# 9                         Cybersecurity  ...                       2.52
# 10                        Cybersecurity  ...                       3.29
# 11                        Cybersecurity  ...                       2.25
# 12          Data management & analytics  ...                       2.14
# 13          Data management & analytics  ...                       3.00
# 14          Data management & analytics  ...                      11.50
# 15      E-commerce & direct-to-consumer  ...                       2.47
# 16      E-commerce & direct-to-consumer  ...                       4.00
# 17      E-commerce & direct-to-consumer  ...                       2.58
# 18                               Edtech  ...                       2.00
# 19                               Edtech  ...                       2.75
# 20                               Edtech  ...                       1.00
# 21                              Fintech  ...                       2.75
# 22                              Fintech  ...                       4.33
# 23                              Fintech  ...                       6.80
# 24                             Hardware  ...                       2.00
# 25                             Hardware  ...                       2.00
# 26                               Health  ...                       1.95
# 27                               Health  ...                       3.11
# 28                               Health  ...                       3.33
# 29         Internet software & services  ...                       2.15
# 30         Internet software & services  ...                       4.35
# 31         Internet software & services  ...                       4.23
# 32          Mobile & telecommunications  ...                       1.83
# 33          Mobile & telecommunications  ...                       3.13
# 34          Mobile & telecommunications  ...                       2.00
# 35                                Other  ...                       1.71
# 36                                Other  ...                       3.00
# 37                                Other  ...                       2.89
# 38  Supply chain, logistics, & delivery  ...                       2.20
# 39  Supply chain, logistics, & delivery  ...                       2.00
# 40  Supply chain, logistics, & delivery  ...                       3.00
# 41                               Travel  ...                       2.67
# 42                               Travel  ...                       4.00
#
# [43 rows x 4 columns]

# %% [markdown]
# Including the first query as a Common Table Expression, we can narrow the scope to the three top-performing_companies

# %%
WITH top_3_industries AS (
SELECT i.industry, COUNT(i.*) AS num_unicorns
FROM industries AS i
INNER JOIN dates AS d
ON i.company_id = d.company_id
WHERE EXTRACT(YEAR FROM d.date_joined) IN (2019,2020, 2021)
GROUP BY i.industry
ORDER BY num_unicorns DESC
LIMIT 3
)
SELECT i.industry,
		EXTRACT(YEAR FROM d.date_joined) AS year,
		COUNT(*) AS num_unicorns,
		ROUND(AVG(f.valuation)/1000000000,2) AS average_valuation_billions
FROM industries AS i
INNER JOIN dates AS d
	ON i.company_id = d.company_id
INNER JOIN funding AS f
	ON i.company_id = f.company_id
WHERE EXTRACT(YEAR FROM d.date_joined) IN (2019,2020,2021)
	AND i.industry IN(SELECT industry FROM top_3_industries)
GROUP BY i.industry, year
ORDER BY i.industry, year DESC
# Out:
#                           industry  ...  average_valuation_billions
# 0  E-commerce & direct-to-consumer  ...                        2.47
# 1  E-commerce & direct-to-consumer  ...                        4.00
# 2  E-commerce & direct-to-consumer  ...                        2.58
# 3                          Fintech  ...                        2.75
# 4                          Fintech  ...                        4.33
# 5                          Fintech  ...                        6.80
# 6     Internet software & services  ...                        2.15
# 7     Internet software & services  ...                        4.35
# 8     Internet software & services  ...                        4.23
#
# [9 rows x 4 columns]
